# %%
from utils import get_best_genome, visualize_genome, get_genome


b = get_best_genome(19, test_name="../data/more nodes")
visualize_genome(b)

# %%
from utils import plot_fitness_stats

plot_fitness_stats(range(0, 32, 1), test_name="../data/rndh",include_best=True)

# %%
from utils import plot_species_count

plot_species_count(range(0, 31, 1), test_name="../data/rndh")
