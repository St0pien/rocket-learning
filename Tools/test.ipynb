# %%
from utils import get_best_genome, visualize_genome, get_genome


b = get_best_genome(19, test_name="../data/stage1")
visualize_genome(b)

# %%
from utils import plot_fitness_stats

plot_fitness_stats(range(0, 19, 1), test_name="../data/stage1",include_best=True)

# %%
from utils import plot_species_count

plot_species_count(range(0, 133, 5), test_name="../data/hard2")
