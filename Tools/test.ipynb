# %%
from utils import get_best_genome, visualize_genome, get_genome


b = get_best_genome(80, test_name="../data/simple")
visualize_genome(b)

# %%
from utils import plot_fitness_stats

plot_fitness_stats(range(0, 580, 10), test_name="../data/simple",include_best=True)

# %%
from utils import plot_species_count

plot_species_count(range(0, 580, 10), test_name="../data/simple")
