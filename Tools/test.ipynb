# %%
from utils import get_best_genome, visualize_genome, get_genome


b = get_best_genome(13, test_name="../data/env")
visualize_genome(b)

# %%
from utils import plot_fitness_stats

plot_fitness_stats(range(0, 24, 1), test_name="../data/env",include_best=False)

# %%
from utils import plot_species_count

plot_species_count(range(0, 24, 2), test_name="../data/env")
