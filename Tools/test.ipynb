# %%
from utils import get_best_genome, visualize_genome, get_genome


b = get_best_genome(499, test_name="../data/xor")
visualize_genome(b)

# %%
from utils import plot_fitness_stats

plot_fitness_stats(range(0, 499, 5), test_name="../data/xor",include_best=False)

# %%
from utils import plot_species_count

plot_species_count(range(0, 499, 5), test_name="../data/xor")
