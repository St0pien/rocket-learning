# %%
import json
import matplotlib.pyplot as plt
import math

with open("../data/plots.json") as f:
    x, y = json.load(f).values()
    plt.title("Fitted model vs true curve")
    plt.plot(x, y, label='model')
    # plt.plot(x, [3 * xn**2 + xn - 5 for xn in x])
    # plt.plot(x, [(math.atan(xn)+1)/2 for xn in x])
    # plt.plot(x,x)
    plt.plot(x, [(xn-0.25)**2 for xn in x], label='true')
    plt.legend()
